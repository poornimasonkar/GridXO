# %% [markdown]
# <a href="https://colab.research.google.com/github/poornimasonkar/GridXO/blob/master/Python_lec_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Output

# %%
print('Hello Wrold')
# Out:
# Hello Wrold

# %% [markdown]
# # Python is case sensitive language
#
# print and Print
#
# are bothe different

# %%
print('Poornima Sonkar')
# Out:
# Poornima Sonkar

# %%
print (7)
# Out:
# 7

# %%
print(1.2)
# Out:
# 1.2

# %%
print(8)
# Out:
# 8

# %%
print(1.27)
# Out:
# 1.27

# %%
print(False)
# Out:
# False

# %%
print('Hello',1,2,3,True)
# Out:
# Hello 1 2 3 True

# %%
print('Hello',1,2,3,True,sep='/')
# Out:
# Hello/1/2/3/True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('Hello',end='-')
print('world')
# Out:
# Hello-world

# %% [markdown]
# Data Type

# %%
#Integer
print(8)
#1*10^309
print(1e309)
# Out:
# 8
# inf

# %%
#Decimal
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('Hello World')
# Out:
# Hello World

# %%
#complex number
print(5+6j)
# Out:
# (5+6j)

# %%
#List (calling it list in Python, but array in C, only a few concepts r different)
print([1,2,3,3,4])
# Out:
# [1, 2, 3, 3, 4]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#set
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name': 'Poornima','gender':'Female','age':'20'})
# Out:
# {'name': 'Poornima', 'gender': 'Female', 'age': '20'}

# %%
#type
type([1,2,3,4,5])
# Out:
# list

# %% [markdown]
# Variable

# %%
#Static vs Dynamic Typing
#Static Vs Dynamic Binding
#stylish declaration techniques

# %%
a=8
print(a)
# Out:
# 8

# %%
a=8
b=9
c=a+b
print(c)
# Out:
# 17

# %%
#Dynamic Typing
a=5
#Static Typing
int a=5

# %%
#Dynamic Binding
a=5
print(a)
a='Poornima'
print(a)
# Out:
# 5
# Poornima

# %%
#Static Binding
int a=5

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# keywords & Identifiers

# %%
import keyword
print("The list of keywords are:")
print(keyword.kwlist)
# Out:
# The list of keywords are:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# User Input

# %%
#Static Vs Dynamic
input ('Enter Email')
# Out:
# Enter Emailstelllanova666@gmail.com
# 'stelllanova666@gmail.com'

# %%
#take input from user
#add 2 numb3er
#print the value
a=int(input('Enter first number'))
b=int(input('Enter second number'))
sum=a+b
print('Sum of the two number is:', sum)
print(type(sum))
print(type(a),type(b))
# Out:
# Enter first number78
# Enter second number87
# Sum of the two number is: 165
# <class 'int'>
# <class 'int'> <class 'int'>

# %% [markdown]
# Literals

# %%
string = 'This is python'
string= "This is python"
char='c'
multiline_str= """this is a multiline str cod ewith multiple lines"""
unicode = u"\U0001f600\U0001f606"
raw_str = r"raw \n string"
print( string )
print(string)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is python
# This is python
# c
# this is a multiline str cod ewith multiple lines
# 😀😆
# raw \n string

# %%
a=0b1010
print(a)
# Out:
# 10

# %%
a=3+14j
print(a.real,a.imag)
# Out:
# 3.0 14.0

# %%
a=True+4
b=False+10
print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10
